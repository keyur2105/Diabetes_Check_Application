# %%
import pandas as pd

# %%
data = pd.read_csv("diabetes_prediction_dataset.csv")
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns",None)
data.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
data.shape
# Out:
# (100000, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
data.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
data = data.apply(lambda x: x.str.strip() if x.dtype == 'object' else x)

# %%
data['gender'].unique()
# Out:
# array(['Female', 'Male', 'Other'], dtype=object)

# %%
data['gender'] = data['gender'].str.replace("Other","Female")

# %%
data['gender'].value_counts()
# Out:
# Female    58570
# Male      41430
# Name: gender, dtype: int64

# %%
data['heart_disease'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
chn = {
    1: "high blood Pressure",
    0: "Normal blood pressure"
}
data['hypertension']=data['hypertension'].replace(chn).astype("object")
data.sample(3)
# Out:
#        gender   age           hypertension  heart_disease smoking_history  \
# 3156   Female  36.0  Normal blood pressure              0         No Info
# 38543  Female  26.0  Normal blood pressure              0         current
# 48206    Male  66.0  Normal blood pressure              1           never
#
#          bmi  HbA1c_level  blood_glucose_level  diabetes
# 3156   32.12          6.2                   80         0
# 38543  41.05          6.5                  140         1
# 48206  29.56          5.0                   90         0

# %%
data['heart_disease'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
data['heart_disease']=data['heart_disease'].map({1:'Heart Disease',0:'No Heart Disease'}).astype("object")
data.sample(3)
# Out:
#        gender   age           hypertension     heart_disease smoking_history  \
# 59161  Female  53.0  Normal blood pressure  No Heart Disease         current
# 64450  Female  47.0  Normal blood pressure  No Heart Disease         No Info
# 16914    Male  80.0  Normal blood pressure  No Heart Disease          former
#
#          bmi  HbA1c_level  blood_glucose_level  diabetes
# 59161  27.32          4.0                  158         0
# 64450  27.32          5.8                   80         0
# 16914  22.68          8.8                  300         1

# %%
data['smoking_history'].unique()
# Out:
# array(['never', 'No Info', 'current', 'former', 'ever', 'not current'],
#       dtype=object)

# %%
data['smoking_history']=data['smoking_history'].map({'never':'Never','No Info':'No Information','current':'Currently','former':'Former','ever':'Ever','not current':"Not Currently"})
data.sample(3)
# Out:
#        gender   age           hypertension     heart_disease smoking_history  \
# 99476  Female  30.0  Normal blood pressure  No Heart Disease  No Information
# 70878  Female  56.0    high blood Pressure  No Heart Disease       Currently
# 78027    Male  34.0  Normal blood pressure  No Heart Disease           Never
#
#          bmi  HbA1c_level  blood_glucose_level  diabetes
# 99476  28.83          6.0                  145         0
# 70878  34.99          6.6                  160         0
# 78027  29.55          3.5                   85         0

# %%
data = data.rename(columns={'bmi':'BMI_Level'})
data.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history',
#        'BMI_Level', 'HbA1c_level', 'blood_glucose_level', 'diabetes'],
#       dtype='object')

# %%
data['HbA1c_level'].unique()
# Out:
# array([6.6, 5.7, 5. , 4.8, 6.5, 6.1, 6. , 5.8, 3.5, 6.2, 4. , 4.5, 9. ,
#        7. , 8.8, 8.2, 7.5, 6.8])

# %%
data['blood_glucose_level'].unique()
# Out:
# array([140,  80, 158, 155,  85, 200, 145, 100, 130, 160, 126, 159,  90,
#        260, 220, 300, 280, 240], dtype=int64)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  object
#  3   heart_disease        100000 non-null  object
#  4   smoking_history      100000 non-null  object
#  5   BMI_Level            100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 6.9+ MB

# %%
data.to_csv("New_df.csv")

# %%
df = pd.read_csv("New_df.csv")
df.shape
# Out:
# (100000, 10)

# %%
df.sample(3)
# Out:
#        Unnamed: 0  gender    age           hypertension     heart_disease  \
# 62621       62621  Female  56.00  Normal blood pressure  No Heart Disease
# 3528         3528    Male  53.00    high blood Pressure  No Heart Disease
# 26222       26222  Female   1.56  Normal blood pressure  No Heart Disease
#
#       smoking_history  BMI_Level  HbA1c_level  blood_glucose_level  diabetes
# 62621           Never      26.52          6.0                  100         0
# 3528            Never      35.27          6.0                   80         0
# 26222  No Information      19.07          6.2                  145         0

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)
df.head()
# Out:
#    gender   age           hypertension     heart_disease smoking_history  \
# 0  Female  80.0  Normal blood pressure     Heart Disease           Never
# 1  Female  54.0  Normal blood pressure  No Heart Disease  No Information
# 2    Male  28.0  Normal blood pressure  No Heart Disease           Never
# 3  Female  36.0  Normal blood pressure  No Heart Disease       Currently
# 4    Male  76.0    high blood Pressure     Heart Disease       Currently
#
#    BMI_Level  HbA1c_level  blood_glucose_level  diabetes
# 0      25.19          6.6                  140         0
# 1      27.32          6.6                   80         0
# 2      27.32          5.7                  158         0
# 3      23.45          5.0                  155         0
# 4      20.14          4.8                  155         0

# %%
X=df.drop(columns=['diabetes'])
y=df['diabetes']
X=X.dropna()
y=y.dropna()
X.shape, y.shape
# Out:
# ((100000, 8), (100000,))

# %%
print(X.isnull().sum())
print(y.isnull().sum())
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# BMI_Level              0
# HbA1c_level            0
# blood_glucose_level    0
# dtype: int64
# 0

# %%
# from sklearn.impute import SimpleImputer
# imputer = SimpleImputer(strategy='mean')
# X['age'] = imputer.fit_transform(X[['age']])
# X['BMI_Level'] = imputer.fit_transform(X[['BMI_Level']])
# X['HbA1c_level'] = imputer.fit_transform(X[['HbA1c_level']])

# %%
X.sample(3), y.sample(3)
# Out:
# (      gender   age           hypertension     heart_disease smoking_history  \
#  4990    Male  57.0    high blood Pressure  No Heart Disease       Currently
#  65830   Male  57.0    high blood Pressure  No Heart Disease       Currently
#  58628   Male  19.0  Normal blood pressure  No Heart Disease           Never
#
#         BMI_Level  HbA1c_level  blood_glucose_level
#  4990       34.28          6.0                  159
#  65830      35.14          7.5                  200
#  58628      35.51          4.5                   85  ,
#  66277    0
#  15428    0
#  25354    0
#  Name: diabetes, dtype: int64)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((70000, 8), (30000, 8), (70000,), (30000,))

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import make_column_transformer

# %%
cat_col = ['gender','hypertension','heart_disease','smoking_history']
num_col = ['age','BMI_Level','HbA1c_level','blood_glucose_level']

# %%
make_col = make_column_transformer((OneHotEncoder(handle_unknown="ignore",categories='auto'),cat_col),
                                (StandardScaler(with_mean=False),num_col),
                                remainder="passthrough"
)
make_col
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('onehotencoder',
#                                  OneHotEncoder(handle_unknown='ignore'),
#                                  ['gender', 'hypertension', 'heart_disease',
#                                   'smoking_history']),
#                                 ('standardscaler',
#                                  StandardScaler(with_mean=False),
#                                  ['age', 'BMI_Level', 'HbA1c_level',
#                                   'blood_glucose_level'])])

# %%
from sklearn.linear_model import LogisticRegression

# %%
regression = LogisticRegression()

# %%
from sklearn.pipeline import make_pipeline

# %%
pipe = make_pipeline(make_col, regression)
pipe
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['gender', 'hypertension',
#                                                    'heart_disease',
#                                                    'smoking_history']),
#                                                  ('standardscaler',
#                                                   StandardScaler(with_mean=False),
#                                                   ['age', 'BMI_Level',
#                                                    'HbA1c_level',
#                                                    'blood_glucose_level'])])),
#                 ('logisticregression', LogisticRegression())])

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['gender', 'hypertension',
#                                                    'heart_disease',
#                                                    'smoking_history']),
#                                                  ('standardscaler',
#                                                   StandardScaler(with_mean=False),
#                                                   ['age', 'BMI_Level',
#                                                    'HbA1c_level',
#                                                    'blood_glucose_level'])])),
#                 ('logisticregression', LogisticRegression())])

# %%
y_pred = pipe.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(y_test,y_pred)
print("Accuracy : ", accuracy)
# Out:
# Accuracy :  0.9602666666666667

# %%
df.sample(10)
# Out:
#        gender   age           hypertension     heart_disease smoking_history  \
# 22283  Female  29.0  Normal blood pressure  No Heart Disease           Never
# 78685    Male   7.0  Normal blood pressure  No Heart Disease           Never
# 44198    Male  26.0  Normal blood pressure  No Heart Disease  No Information
# 77319    Male  15.0  Normal blood pressure  No Heart Disease           Never
# 44456    Male  51.0  Normal blood pressure  No Heart Disease       Currently
# 94723    Male  77.0  Normal blood pressure     Heart Disease  No Information
# 79638  Female  34.0  Normal blood pressure  No Heart Disease  No Information
# 76820    Male  42.0  Normal blood pressure  No Heart Disease           Never
# 71945  Female  20.0  Normal blood pressure  No Heart Disease  No Information
# 79422    Male   7.0  Normal blood pressure  No Heart Disease  No Information
#
#        BMI_Level  HbA1c_level  blood_glucose_level  diabetes
# 22283      28.80          4.8                  145         0
# ...

# %%
predict_data = pd.DataFrame([['Female',60,'Normal blood pressure','No Heart Disease','Currently',59,7,140]],
                columns=['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history',
                           'BMI_Level', 'HbA1c_level', 'blood_glucose_level'])
predict_data
# Out:
#    gender  age           hypertension     heart_disease smoking_history  \
# 0  Female   60  Normal blood pressure  No Heart Disease       Currently
#
#    BMI_Level  HbA1c_level  blood_glucose_level
# 0         59            7                  140

# %%
Ans = pipe.predict(predict_data)
print(Ans)
if Ans == 1:
    print("You are making new history because you have diabetes.💥💥")
else:
    print("Congratulation, you have not diabetes.🍾🍾")
# Out:
# [1]
# You are making new history because you have diabetes.💥💥

# %%
import pickle

# %%
pickle.dump(pipe,open("pipe.pickle","wb"))
pickle.dump(df,open("df.pickle","wb"))
print("Succesfully Pickle File created")
# Out:
# Succesfully Pickle File created
