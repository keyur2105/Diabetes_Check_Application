# %%
import pandas as pd

# %%
data = pd.read_csv("diabetes_prediction_dataset.csv")
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns",None)
data.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
data.shape
# Out:
# (100000, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
data.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
data = data.apply(lambda x: x.str.strip() if x.dtype == 'object' else x)

# %%
data['gender'].unique()
# Out:
# array(['Female', 'Male', 'Other'], dtype=object)

# %%
data['gender'] = data['gender'].str.replace("Other","Female")

# %%
data['gender'].value_counts()
# Out:
# gender
# Female    58570
# Male      41430
# Name: count, dtype: int64

# %%
data['heart_disease'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
chn = {
    1: "high blood Pressure",
    0: "Normal blood pressure"
}
data['hypertension']=data['hypertension'].replace(chn).astype("object")
data.sample(3)
# Out:
#        gender   age           hypertension  heart_disease smoking_history  \
# 95507  Female   3.0  Normal blood pressure              0         No Info
# 39239    Male  63.0  Normal blood pressure              0         No Info
# 28172  Female  77.0    high blood Pressure              0           never
#
#          bmi  HbA1c_level  blood_glucose_level  diabetes
# 95507  26.10          6.6                  160         0
# 39239  35.87          8.8                  155         1
# 28172  28.42          6.1                  200         1

# %%
data['heart_disease'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
data['heart_disease']=data['heart_disease'].map({1:'Heart Disease',0:'No Heart Disease'}).astype("object")
data.sample(3)
# Out:
#       gender   age           hypertension     heart_disease smoking_history  \
# 93151   Male  12.0  Normal blood pressure  No Heart Disease         No Info
# 55551   Male  43.0  Normal blood pressure  No Heart Disease           never
# 85139   Male  20.0  Normal blood pressure  No Heart Disease           never
#
#          bmi  HbA1c_level  blood_glucose_level  diabetes
# 93151  17.67          6.6                  100         0
# 55551  27.32          5.7                  200         0
# 85139  21.71          4.0                  200         0

# %%
data['smoking_history'].unique()
# Out:
# array(['never', 'No Info', 'current', 'former', 'ever', 'not current'],
#       dtype=object)

# %%
data['smoking_history']=data['smoking_history'].map({'never':'Never','No Info':'No Information','current':'Currently','former':'Former','ever':'Ever','not current':"Not Currently"})
data.sample(3)
# Out:
#        gender   age           hypertension     heart_disease smoking_history  \
# 89086  Female  20.0  Normal blood pressure  No Heart Disease            Ever
# 40062    Male  64.0  Normal blood pressure  No Heart Disease       Currently
# 49983    Male  29.0  Normal blood pressure  No Heart Disease  No Information
#
#          bmi  HbA1c_level  blood_glucose_level  diabetes
# 89086  27.49          6.1                  100         0
# 40062  27.81          4.5                  130         0
# 49983  27.32          5.7                   85         0

# %%
data = data.rename(columns={'bmi':'BMI_Level'})
data.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history',
#        'BMI_Level', 'HbA1c_level', 'blood_glucose_level', 'diabetes'],
#       dtype='object')

# %%
data['HbA1c_level'].unique()
# Out:
# array([6.6, 5.7, 5. , 4.8, 6.5, 6.1, 6. , 5.8, 3.5, 6.2, 4. , 4.5, 9. ,
#        7. , 8.8, 8.2, 7.5, 6.8])

# %%
data['blood_glucose_level'].unique()
# Out:
# array([140,  80, 158, 155,  85, 200, 145, 100, 130, 160, 126, 159,  90,
#        260, 220, 300, 280, 240], dtype=int64)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  object
#  3   heart_disease        100000 non-null  object
#  4   smoking_history      100000 non-null  object
#  5   BMI_Level            100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 6.9+ MB

# %%
X=data.drop(columns=['diabetes'])
y=data['diabetes']
X=X.dropna()
y=y.dropna()
X.shape, y.shape
# Out:
# ((100000, 8), (100000,))

# %%
print(X.isnull().sum())
print(y.isnull().sum())
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# BMI_Level              0
# HbA1c_level            0
# blood_glucose_level    0
# dtype: int64
# 0

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean')
X['age'] = imputer.fit_transform(X[['age']])
X['BMI_Level'] = imputer.fit_transform(X[['BMI_Level']])
X['HbA1c_level'] = imputer.fit_transform(X[['HbA1c_level']])

# %%
X.sample(3), y.sample(3)
# Out:
# (       gender   age           hypertension     heart_disease smoking_history  \
#  78328  Female  60.0  Normal blood pressure  No Heart Disease  No Information
#  53240  Female  57.0  Normal blood pressure  No Heart Disease  No Information
#  4436   Female  52.0    high blood Pressure  No Heart Disease           Never
#
#         BMI_Level  HbA1c_level  blood_glucose_level
#  78328      27.32          4.8                  145
#  53240      27.32          6.6                  126
#  4436       34.61          5.7                  160  ,
#  32809    0
#  54454    0
#  70689    1
#  Name: diabetes, dtype: int64)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((70000, 8), (30000, 8), (70000,), (30000,))

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import make_column_transformer

# %%
cat_col = ['gender','hypertension','heart_disease','smoking_history']
num_col = ['age','BMI_Level','HbA1c_level','blood_glucose_level']

# %%
make_col = make_column_transformer((OneHotEncoder(handle_unknown="ignore",categories='auto'),cat_col),
                                (StandardScaler(with_mean=False),num_col),
                                remainder="passthrough"
)
make_col
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('onehotencoder',
#                                  OneHotEncoder(handle_unknown='ignore'),
#                                  ['gender', 'hypertension', 'heart_disease',
#                                   'smoking_history']),
#                                 ('standardscaler',
#                                  StandardScaler(with_mean=False),
#                                  ['age', 'BMI_Level', 'HbA1c_level',
#                                   'blood_glucose_level'])])

# %%
from sklearn.linear_model import LogisticRegression

# %%
regression = LogisticRegression()

# %%
from sklearn.pipeline import make_pipeline

# %%
pipe = make_pipeline(make_col, regression)
pipe
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['gender', 'hypertension',
#                                                    'heart_disease',
#                                                    'smoking_history']),
#                                                  ('standardscaler',
#                                                   StandardScaler(with_mean=False),
#                                                   ['age', 'BMI_Level',
#                                                    'HbA1c_level',
#                                                    'blood_glucose_level'])])),
#                 ('logisticregression', LogisticRegression())])

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['gender', 'hypertension',
#                                                    'heart_disease',
#                                                    'smoking_history']),
#                                                  ('standardscaler',
#                                                   StandardScaler(with_mean=False),
#                                                   ['age', 'BMI_Level',
#                                                    'HbA1c_level',
#                                                    'blood_glucose_level'])])),
#                 ('logisticregression', LogisticRegression())])

# %%
y_pred = pipe.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(y_test,y_pred)
print("Accuracy : ", accuracy)
# Out:
# Accuracy :  0.9602666666666667

# %%
data.sample(10)
# Out:
#        gender   age           hypertension     heart_disease smoking_history  \
# 37643  Female  70.0  Normal blood pressure  No Heart Disease           Never
# 39155  Female  45.0  Normal blood pressure  No Heart Disease  No Information
# 40411  Female  60.0    high blood Pressure  No Heart Disease          Former
# 8275   Female  45.0  Normal blood pressure  No Heart Disease          Former
# 82198    Male  20.0  Normal blood pressure  No Heart Disease           Never
# 7145     Male  42.0  Normal blood pressure  No Heart Disease       Currently
# 73218  Female  69.0  Normal blood pressure  No Heart Disease           Never
# 25122  Female   8.0  Normal blood pressure  No Heart Disease  No Information
# 2878   Female  48.0  Normal blood pressure  No Heart Disease            Ever
# 73137  Female  21.0  Normal blood pressure  No Heart Disease            Ever
#
#        BMI_Level  HbA1c_level  blood_glucose_level  diabetes
# 37643      27.12          4.8                   80         0
# 39155      27.32          4.0                  145         0
# 40411      22.57          5.7                  126         0
# 8275       33.91          6.2                  200         0
# 82198      24.08          3.5                  126         0
# 7145       59.27          7.0                  159         1
# 73218      24.21          6.6                   85         0
# 25122      27.32          5.7                  160         0
# 2878       19.81          4.5                  126         0
# 73137      25.06          4.5                  200         0

# %%
predict_data = pd.DataFrame([['Female',60,'Normal blood pressure','No Heart Disease','Currently',59,7,140]],
                columns=['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history',
                           'BMI_Level', 'HbA1c_level', 'blood_glucose_level'])
predict_data
# Out:
#    gender  age           hypertension     heart_disease smoking_history  \
# 0  Female   60  Normal blood pressure  No Heart Disease       Currently
#
#    BMI_Level  HbA1c_level  blood_glucose_level
# 0         59            7                  140

# %%
Ans = pipe.predict(predict_data)
print(Ans)
if Ans == 1:
    print("You are making new history because you have diabetes.💥💥")
else:
    print("Congratulation, you have not diabetes.🍾🍾")
# Out:
# [1]
# You are making new history because you have diabetes.💥💥

# %%
import pickle

# %%
pickle.dump(pipe,open("pipe.pickle","wb"))
pickle.dump(data,open("data.pickel","wb"))
print("Succesfully Pickle File created")
# Out:
# Succesfully Pickle File created
